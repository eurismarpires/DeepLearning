# %%
from music21 import *
from IPython.display import *

# %%
f = "http://www.classicalguitarmidi.com/subivic/Brouwer_Etude_No1.mid"
midi_stream = converter.parse(f)

# %%
Image(filename=midi_stream.write('lily.png'))

# %%
lista_notas = [] 
for m in midi_stream.measures(1,None):
    time_sig = m.timeSignature           
    for nr in m.flat.notesAndRests:
        offset_loc = nr.offset               
        notas = []               
        if isinstance(nr, note.Note):
            pitch = nr.pitch.midi            
            notas.append(pitch)
        else:
            notas = [pitch.midi for pitch in nr]
        #print(nr.offset,notas)        
        linha =(nr.offset,notas)              
        lista_notas.append([offset_loc,notas])

# %%
tempo_anterior = 0.0
for i, a in enumerate(lista_notas):    
    tempo = lista_notas[i+1][0] - lista_notas[i][0] if i+1 < len(lista_notas) else lista_notas[i][0] - lista_notas[i-1][0]    
    lista_notas[i].append(tempo)
    print(i, a)
# Out:
# 0 [0.0, [40], 0.5]
# 1 [0.5, [59, 55], 0.5]
# 2 [1.0, [59, 55], 0.5]
# 3 [1.5, [50], 0.5]
# 4 [2.0, [59, 55], 0.5]
# 5 [2.5, [50], 0.5]
# 6 [3.0, [54], 0.5]
# 7 [3.5, [59, 55], 0.5]
# 8 [4.0, [52], 0.5]
# 9 [4.5, [59, 55], 0.5]
# 10 [5.0, [47], 0.5]
# 11 [5.5, [45], 0.5]
# 12 [6.0, [59, 55], 0.5]
# 13 [6.5, [48], 0.5]
# 14 [7.0, [59, 55], 0.5]
# 15 [7.5, [47], 0.5]
# 16 [8.0, [40], 0.5]
# 17 [8.5, [59, 55], 0.5]
# 18 [9.0, [59, 55], 0.5]
# 19 [9.5, [50], 0.5]
# 20 [10.0, [59, 55], 0.5]
# 21 [10.5, [50], 0.5]
# 22 [11.0, [54], 0.5]
# 23 [11.5, [59, 55], 0.5]
# 24 [12.0, [52], 0.5]
# 25 [12.5, [59, 55], 0.5]
# 26 [13.0, [47], 0.5]
# 27 [13.5, [45], 0.5]
# 28 [14.0, [59, 55], 0.5]
# 29 [14.5, [49], 0.5]
# 30 [15.0, [59, 55], 0.5]
# 31 [15.5, [47], 0.5]
# 32 [16.0, [40], 0.5]
# 33 [16.5, [59, 55], 0.5]
# 34 [17.0, [59, 55], 0.5]
# 35 [17.5, [48], 0.5]
# 36 [18.0, [59, 55], 0.5]
# 37 [18.5, [41], 0.5]
# 38 [19.0, [41], 0.5]
# 39 [19.5, [59, 55], 0.5]
# 40 [20.0, [48], 0.5]
# 41 [20.5, [59, 55], 0.5]
# 42 [21.0, [41], 0.5]
# 43 [21.5, [41], 0.5]
# 44 [22.0, [59, 55], 0.5]
# 45 [22.5, [48], 0.5]
# 46 [23.0, [59, 55], 0.5]
# 47 [23.5, [47], 0.5]
# 48 [24.0, [40], 0.5]
# 49 [24.5, [59, 55], 0.5]
# 50 [25.0, [59, 55], 0.5]
# 51 [25.5, [48], 0.5]
# 52 [26.0, [59, 55], 0.5]
# 53 [26.5, [41], 0.5]
# 54 [27.0, [41], 0.5]
# 55 [27.5, [59, 55], 0.5]
# 56 [28.0, [48], 0.5]
# 57 [28.5, [59, 55], 0.5]
# 58 [29.0, [41], 0.5]
# 59 [29.5, [41], 0.5]
# 60 [30.0, [59, 55], 0.5]
# 61 [30.5, [48], 0.5]
# 62 [31.0, [59, 55], 0.5]
# 63 [31.5, [47], 0.5]
# 64 [32.0, [40], 0.5]
# 65 [32.5, [59, 55], 0.5]
# 66 [33.0, [59, 55], 0.5]
# 67 [33.5, [61, 57], 0.5]
# 68 [34.0, [61, 57], 0.5]
# 69 [34.5, [45], 0.5]
# 70 [35.0, [45], 0.5]
# 71 [35.5, [43], 0.5]
# 72 [36.0, [43], 0.5]
# 73 [36.5, [59, 55], 0.5]
# 74 [37.0, [59, 55], 0.5]
# 75 [37.5, [61, 57], 0.5]
# 76 [38.0, [61, 57], 0.5]
# 77 [38.5, [45], 0.5]
# 78 [39.0, [45], 0.5]
# 79 [39.5, [50], 0.5]
# 80 [40.0, [50], 0.5]
# 81 [40.5, [59, 55], 0.5]
# 82 [41.0, [59, 55], 0.5]
# 83 [41.5, [59, 55], 1.0]
# 84 [42.5, [55], 0.5]
# 85 [43.0, [55, 50], 0.5]
# 86 [43.5, [55, 50], 0.5]
# 87 [44.0, [40], 0.5]
# 88 [44.5, [55, 50], 0.5]
# 89 [45.0, [55, 50], 0.5]
# 90 [45.5, [49], 0.5]
# 91 [46.0, [55, 50], 0.5]
# 92 [46.5, [42], 0.5]
# 93 [47.0, [42], 0.5]
# 94 [47.5, [55, 50], 0.5]
# 95 [48.0, [50], 0.5]
# 96 [48.5, [55], 0.5]
# 97 [49.0, [43], 0.5]
# 98 [49.5, [43], 0.5]
# 99 [50.0, [55, 50], 0.5]
# 100 [50.5, [48], 0.5]
# 101 [51.0, [55, 50], 0.5]
# 102 [51.5, [41], 0.5]
# 103 [52.0, [41], 0.5]
# 104 [52.5, [55, 50], 0.5]
# 105 [53.0, [55, 50], 0.5]
# 106 [53.5, [57, 50], 0.5]
# 107 [54.0, [57, 50], 0.5]
# 108 [54.5, [45], 0.5]
# 109 [55.0, [45], 0.5]
# 110 [55.5, [48], 0.5]
# 111 [56.0, [48], 0.5]
# 112 [56.5, [57, 50], 0.5]
# 113 [57.0, [57, 50], 0.5]
# 114 [57.5, [59, 57], 0.5]
# 115 [58.0, [59, 57], 0.5]
# 116 [58.5, [47], 0.5]
# 117 [59.0, [47], 0.5]
# 118 [59.5, [40], 0.5]
# 119 [60.0, [40], 0.5]
# 120 [60.5, [55, 50], 0.5]
# 121 [61.0, [55, 50], 0.5]
# 122 [61.5, [49], 0.5]
# 123 [62.0, [55, 50], 1.5]
# 124 [63.5, [55, 50], 0.5]
# 125 [64.0, [40], 0.5]
# 126 [64.5, [55, 50], 0.5]
# 127 [65.0, [55, 50], 0.5]
# 128 [65.5, [49], 0.5]
# 129 [66.0, [55, 50], 1.5]
# 130 [67.5, [55, 50], 0.5]
# 131 [68.0, [40], 0.5]
# 132 [68.5, [59, 55], 0.5]
# 133 [69.0, [59, 55], 0.5]
# 134 [69.5, [50], 0.5]
# 135 [70.0, [59, 55], 0.5]
# 136 [70.5, [50], 0.5]
# 137 [71.0, [54], 0.5]
# 138 [71.5, [59, 55], 0.5]
# 139 [72.0, [52], 0.5]
# 140 [72.5, [59, 55], 0.5]
# 141 [73.0, [47], 0.5]
# 142 [73.5, [45], 0.5]
# 143 [74.0, [59, 55], 0.5]
# 144 [74.5, [48], 0.5]
# 145 [75.0, [59, 55], 0.5]
# 146 [75.5, [47], 0.5]
# 147 [76.0, [40], 0.5]
# 148 [76.5, [59, 55], 0.5]
# 149 [77.0, [59, 55], 0.5]
# 150 [77.5, [52], 0.5]
# 151 [78.0, [59, 55], 0.5]
# 152 [78.5, [50], 0.5]
# 153 [79.0, [54], 0.5]
# 154 [79.5, [59, 55], 0.5]
# 155 [80.0, [52], 0.5]
# 156 [80.5, [59, 55], 0.5]
# 157 [81.0, [47], 0.5]
# 158 [81.5, [45], 0.5]
# 159 [82.0, [59, 55], 0.5]
# 160 [82.5, [49], 0.5]
# 161 [83.0, [59, 55], 0.5]
# 162 [83.5, [47], 0.5]
# 163 [84.0, [40], 0.5]
# 164 [84.5, [59, 55], 0.5]
# 165 [85.0, [59, 55], 0.5]
# 166 [85.5, [48], 0.5]
# 167 [86.0, [59, 55], 0.5]
# 168 [86.5, [41], 0.5]
# 169 [87.0, [41], 0.5]
# 170 [87.5, [59, 55], 0.5]
# 171 [88.0, [48], 0.5]
# 172 [88.5, [59, 55], 0.5]
# 173 [89.0, [41], 0.5]
# 174 [89.5, [41], 0.5]
# 175 [90.0, [59, 55], 0.5]
# 176 [90.5, [48], 0.5]
# 177 [91.0, [59, 55], 0.5]
# 178 [91.5, [48], 0.5]
# 179 [92.0, [40], 0.5]
# 180 [92.5, [59, 55], 0.5]
# 181 [93.0, [59, 55], 0.5]
# 182 [93.5, [48], 0.5]
# 183 [94.0, [59, 55], 0.5]
# 184 [94.5, [41], 0.5]
# 185 [95.0, [41], 0.5]
# 186 [95.5, [59, 55], 0.5]
# 187 [96.0, [48], 0.5]
# 188 [96.5, [59, 55], 0.5]
# 189 [97.0, [41], 0.5]
# 190 [97.5, [41], 0.5]
# 191 [98.0, [59, 55], 0.5]
# 192 [98.5, [48], 0.5]
# 193 [99.0, [59, 55], 0.5]
# 194 [99.5, [47], 0.5]
# 195 [100.0, [40], 0.5]
# 196 [100.5, [59, 55], 0.5]
# 197 [101.0, [59, 55], 0.5]
# 198 [101.5, [59, 55], 1.0]
# 199 [102.5, [59, 55], 1.0]
# 200 [103.5, [59, 55], 1.0]

# %%
lista_notas
# Out:
# [[0.0, [40], 0.5],
#  [0.5, [59, 55], 0.5],
#  [1.0, [59, 55], 0.5],
#  [1.5, [50], 0.5],
#  [2.0, [59, 55], 0.5],
#  [2.5, [50], 0.5],
#  [3.0, [54], 0.5],
#  [3.5, [59, 55], 0.5],
#  [4.0, [52], 0.5],
#  [4.5, [59, 55], 0.5],
#  [5.0, [47], 0.5],
#  [5.5, [45], 0.5],
#  [6.0, [59, 55], 0.5],
#  [6.5, [48], 0.5],
#  [7.0, [59, 55], 0.5],
#  [7.5, [47], 0.5],
#  [8.0, [40], 0.5],
#  [8.5, [59, 55], 0.5],
#  [9.0, [59, 55], 0.5],
#  [9.5, [50], 0.5],
#  [10.0, [59, 55], 0.5],
#  [10.5, [50], 0.5],
#  [11.0, [54], 0.5],
#  [11.5, [59, 55], 0.5],
#  [12.0, [52], 0.5],
#  [12.5, [59, 55], 0.5],
#  [13.0, [47], 0.5],
#  [13.5, [45], 0.5],
#  [14.0, [59, 55], 0.5],
#  [14.5, [49], 0.5],
#  [15.0, [59, 55], 0.5],
#  [15.5, [47], 0.5],
#  [16.0, [40], 0.5],
#  [16.5, [59, 55], 0.5],
#  [17.0, [59, 55], 0.5],
#  [17.5, [48], 0.5],
#  [18.0, [59, 55], 0.5],
#  [18.5, [41], 0.5],
#  [19.0, [41], 0.5],
#  [19.5, [59, 55], 0.5],
#  [20.0, [48], 0.5],
#  [20.5, [59, 55], 0.5],
#  [21.0, [41], 0.5],
#  [21.5, [41], 0.5],
#  [22.0, [59, 55], 0.5],
#  [22.5, [48], 0.5],
#  [23.0, [59, 55], 0.5],
#  [23.5, [47], 0.5],
#  [24.0, [40], 0.5],
#  [24.5, [59, 55], 0.5],
#  [25.0, [59, 55], 0.5],
#  [25.5, [48], 0.5],
#  [26.0, [59, 55], 0.5],
#  [26.5, [41], 0.5],
#  [27.0, [41], 0.5],
#  [27.5, [59, 55], 0.5],
#  [28.0, [48], 0.5],
#  [28.5, [59, 55], 0.5],
#  [29.0, [41], 0.5],
#  [29.5, [41], 0.5],
#  [30.0, [59, 55], 0.5],
#  [30.5, [48], 0.5],
#  [31.0, [59, 55], 0.5],
#  [31.5, [47], 0.5],
#  [32.0, [40], 0.5],
#  [32.5, [59, 55], 0.5],
#  [33.0, [59, 55], 0.5],
#  [33.5, [61, 57], 0.5],
#  [34.0, [61, 57], 0.5],
#  [34.5, [45], 0.5],
#  [35.0, [45], 0.5],
#  [35.5, [43], 0.5],
#  [36.0, [43], 0.5],
#  [36.5, [59, 55], 0.5],
#  [37.0, [59, 55], 0.5],
#  [37.5, [61, 57], 0.5],
#  [38.0, [61, 57], 0.5],
#  [38.5, [45], 0.5],
#  [39.0, [45], 0.5],
#  [39.5, [50], 0.5],
#  [40.0, [50], 0.5],
#  [40.5, [59, 55], 0.5],
#  [41.0, [59, 55], 0.5],
#  [41.5, [59, 55], 1.0],
#  [42.5, [55], 0.5],
#  [43.0, [55, 50], 0.5],
#  [43.5, [55, 50], 0.5],
#  [44.0, [40], 0.5],
#  [44.5, [55, 50], 0.5],
#  [45.0, [55, 50], 0.5],
#  [45.5, [49], 0.5],
#  [46.0, [55, 50], 0.5],
#  [46.5, [42], 0.5],
#  [47.0, [42], 0.5],
#  [47.5, [55, 50], 0.5],
#  [48.0, [50], 0.5],
#  [48.5, [55], 0.5],
#  [49.0, [43], 0.5],
#  [49.5, [43], 0.5],
#  [50.0, [55, 50], 0.5],
#  [50.5, [48], 0.5],
#  [51.0, [55, 50], 0.5],
#  [51.5, [41], 0.5],
#  [52.0, [41], 0.5],
#  [52.5, [55, 50], 0.5],
#  [53.0, [55, 50], 0.5],
#  [53.5, [57, 50], 0.5],
#  [54.0, [57, 50], 0.5],
#  [54.5, [45], 0.5],
#  [55.0, [45], 0.5],
#  [55.5, [48], 0.5],
#  [56.0, [48], 0.5],
#  [56.5, [57, 50], 0.5],
#  [57.0, [57, 50], 0.5],
#  [57.5, [59, 57], 0.5],
#  [58.0, [59, 57], 0.5],
#  [58.5, [47], 0.5],
#  [59.0, [47], 0.5],
#  [59.5, [40], 0.5],
#  [60.0, [40], 0.5],
#  [60.5, [55, 50], 0.5],
#  [61.0, [55, 50], 0.5],
#  [61.5, [49], 0.5],
#  [62.0, [55, 50], 1.5],
#  [63.5, [55, 50], 0.5],
#  [64.0, [40], 0.5],
#  [64.5, [55, 50], 0.5],
#  [65.0, [55, 50], 0.5],
#  [65.5, [49], 0.5],
#  [66.0, [55, 50], 1.5],
#  [67.5, [55, 50], 0.5],
#  [68.0, [40], 0.5],
#  [68.5, [59, 55], 0.5],
#  [69.0, [59, 55], 0.5],
#  [69.5, [50], 0.5],
#  [70.0, [59, 55], 0.5],
#  [70.5, [50], 0.5],
#  [71.0, [54], 0.5],
#  [71.5, [59, 55], 0.5],
#  [72.0, [52], 0.5],
#  [72.5, [59, 55], 0.5],
#  [73.0, [47], 0.5],
#  [73.5, [45], 0.5],
#  [74.0, [59, 55], 0.5],
#  [74.5, [48], 0.5],
#  [75.0, [59, 55], 0.5],
#  [75.5, [47], 0.5],
#  [76.0, [40], 0.5],
#  [76.5, [59, 55], 0.5],
#  [77.0, [59, 55], 0.5],
#  [77.5, [52], 0.5],
#  [78.0, [59, 55], 0.5],
#  [78.5, [50], 0.5],
#  [79.0, [54], 0.5],
#  [79.5, [59, 55], 0.5],
#  [80.0, [52], 0.5],
#  [80.5, [59, 55], 0.5],
#  [81.0, [47], 0.5],
#  [81.5, [45], 0.5],
#  [82.0, [59, 55], 0.5],
#  [82.5, [49], 0.5],
#  [83.0, [59, 55], 0.5],
#  [83.5, [47], 0.5],
#  [84.0, [40], 0.5],
#  [84.5, [59, 55], 0.5],
#  [85.0, [59, 55], 0.5],
#  [85.5, [48], 0.5],
#  [86.0, [59, 55], 0.5],
#  [86.5, [41], 0.5],
#  [87.0, [41], 0.5],
#  [87.5, [59, 55], 0.5],
#  [88.0, [48], 0.5],
#  [88.5, [59, 55], 0.5],
#  [89.0, [41], 0.5],
#  [89.5, [41], 0.5],
#  [90.0, [59, 55], 0.5],
#  [90.5, [48], 0.5],
#  [91.0, [59, 55], 0.5],
#  [91.5, [48], 0.5],
#  [92.0, [40], 0.5],
#  [92.5, [59, 55], 0.5],
#  [93.0, [59, 55], 0.5],
#  [93.5, [48], 0.5],
#  [94.0, [59, 55], 0.5],
#  [94.5, [41], 0.5],
#  [95.0, [41], 0.5],
#  [95.5, [59, 55], 0.5],
#  [96.0, [48], 0.5],
#  [96.5, [59, 55], 0.5],
#  [97.0, [41], 0.5],
#  [97.5, [41], 0.5],
#  [98.0, [59, 55], 0.5],
#  [98.5, [48], 0.5],
#  [99.0, [59, 55], 0.5],
#  [99.5, [47], 0.5],
#  [100.0, [40], 0.5],
#  [100.5, [59, 55], 0.5],
#  [101.0, [59, 55], 0.5],
#  [101.5, [59, 55], 1.0],
#  [102.5, [59, 55], 1.0],
#  [103.5, [59, 55], 1.0]]
