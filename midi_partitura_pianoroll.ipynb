# %%
from music21 import *
from IPython.display import *

# %%
f = "http://www.classicalguitarmidi.com/subivic/Sor_Study_no6.mid"
midi_stream = converter.parse(f)
Image(filename=midi_stream.measures(0,4).write('lily.png'))

# %%
midi_stream.measures(0, 4).plot()

# %%
midi_stream.measures(0, 4).show('text')
# Out:
# {0.0} <music21.stream.Part 0x7f0791010d68>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.instrument.Lute Lute>
#         {0.0} <music21.instrument.Lute Lute>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.tempo.MetronomeMark Quarter=105.0>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 1/4>
#         {0.0} <music21.note.Rest rest>
#         {0.5} <music21.note.Note A>
#     {1.0} <music21.stream.Measure 2 offset=1.0>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F#>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {5.0} <music21.stream.Measure 3 offset=5.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note F#>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {9.0} <music21.stream.Measure 4 offset=9.0>
# ...
